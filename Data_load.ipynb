# %% [markdown]
# <a href="https://colab.research.google.com/github/johanjun/dacon_growthperiod/blob/main/Data_load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## library import
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
import re
from PIL import Image
import shutil
from sklearn.model_selection import train_test_split
import random
import matplotlib.pyplot as plt
from glob import glob
import pandas as pd
from tqdm import tqdm

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# %%
root_dir = '/content/drive/MyDrive/dacon_growthperiod/open'
train_data_dir = os.path.join(root_dir, 'train_dataset')
test_data_dir = os.path.join(root_dir, 'test_dataset')

# %%
bt_train = glob(train_data_dir + '/BC/*')
bt_train_name = [x[-5:] for x in bt_train]

lt_train = glob(train_data_dir + '/LT/*')
lt_train_name = [x[-5:] for x in lt_train]

# %%
bt_images = {key: glob(name + '/*.png') for key, name in zip(bt_train_name, bt_train)}
lt_images = {key: glob(name + '/*.png') for key, name in zip(lt_train_name, lt_train)}

# %%
def extract_day(images):
    day = int(images.split('.')[-2][-2:])
    return day

def make_day_array(images):
    day_array = np.array([extract_day(x) for x in images])
    return day_array

# %%
bt_dayes = {key: make_day_array(bt_images[key]) for key in bt_train_name}
lt_dayes = {key: make_day_array(lt_images[key]) for key in lt_train_name}

# %%
bt_dfs = []

for i in bt_train_name:
    bt_df = pd.DataFrame({
        'file_name': bt_images[i],
        'day': bt_dayes[i],
        'species': 'bc',
        'version': i
    })
    bt_dfs.append(bt_df)
    
lt_dfs = []

for i in lt_train_name:
    lt_df = pd.DataFrame({
        'file_name': lt_images[i],
        'day': lt_dayes[i],
        'species': 'lt',
        'version': i
    })
    lt_dfs.append(lt_df)

bf_dataframe = pd.concat(bt_dfs).reset_index(drop=True)
lt_dataframe = pd.concat(lt_dfs).reset_index(drop=True)

total_dataframe = pd.concat([bf_dataframe, lt_dataframe]).reset_index(drop=True)
total_dataframe
# Out:
#                                              file_name  day species version
# 0    /content/drive/MyDrive/dacon_growthperiod/open...    1      bc   BC_01
# 1    /content/drive/MyDrive/dacon_growthperiod/open...    2      bc   BC_01
# 2    /content/drive/MyDrive/dacon_growthperiod/open...    3      bc   BC_01
# 3    /content/drive/MyDrive/dacon_growthperiod/open...    4      bc   BC_01
# 4    /content/drive/MyDrive/dacon_growthperiod/open...    5      bc   BC_01
# 5    /content/drive/MyDrive/dacon_growthperiod/open...    6      bc   BC_01
# 6    /content/drive/MyDrive/dacon_growthperiod/open...    8      bc   BC_01
# 7    /content/drive/MyDrive/dacon_growthperiod/open...    9      bc   BC_01
# 8    /content/drive/MyDrive/dacon_growthperiod/open...   10      bc   BC_01
# 9    /content/drive/MyDrive/dacon_growthperiod/open...   11      bc   BC_01
# 10   /content/drive/MyDrive/dacon_growthperiod/open...   12      bc   BC_01
# 11   /content/drive/MyDrive/dacon_growthperiod/open...   13      bc   BC_01
# 12   /content/drive/MyDrive/dacon_growthperiod/open...   14      bc   BC_01
# 13   /content/drive/MyDrive/dacon_growthperiod/open...   15      bc   BC_01
# 92   /content/drive/MyDrive/dacon_growthperiod/open...   14      bc   BC_03
# 93   /content/drive/MyDrive/dacon_growthperiod/open...   15      bc   BC_03
# 94   /content/drive/MyDrive/dacon_growthperiod/open...   16      bc   BC_03
# 95   /content/drive/MyDrive/dacon_growthperiod/open...   17      bc   BC_03
# 96   /content/drive/MyDrive/dacon_growthperiod/open...   18      bc   BC_03
# 97   /content/drive/MyDrive/dacon_growthperiod/open...   19      bc   BC_03
# 98   /content/drive/MyDrive/dacon_growthperiod/open...   20      bc   BC_03
# 99   /content/drive/MyDrive/dacon_growthperiod/open...   21      bc   BC_03
# 100  /content/drive/MyDrive/dacon_growthperiod/open...   22      bc   BC_03
# 101  /content/drive/MyDrive/dacon_growthperiod/open...   23      bc   BC_03
# 102  /content/drive/MyDrive/dacon_growthperiod/open...   24      bc   BC_03
# 103  /content/drive/MyDrive/dacon_growthperiod/open...   25      bc   BC_03
# 104  /content/drive/MyDrive/dacon_growthperiod/open...   26      bc   BC_03
# 105  /content/drive/MyDrive/dacon_growthperiod/open...   27      bc   BC_03
# 106  /content/drive/MyDrive/dacon_growthperiod/open...   28      bc   BC_03
# 107  /content/drive/MyDrive/dacon_growthperiod/open...   29      bc   BC_03
# 108  /content/drive/MyDrive/dacon_growthperiod/open...   30      bc   BC_03
# 109  /content/drive/MyDrive/dacon_growthperiod/open...   31      bc   BC_03
# 110  /content/drive/MyDrive/dacon_growthperiod/open...   32      bc   BC_03
# 111  /content/drive/MyDrive/dacon_growthperiod/open...   33      bc   BC_03
# 112  /content/drive/MyDrive/dacon_growthperiod/open...   34      bc   BC_03
# 113  /content/drive/MyDrive/dacon_growthperiod/open...   35      bc   BC_03
# 114  /content/drive/MyDrive/dacon_growthperiod/open...   36      bc   BC_03
# 115  /content/drive/MyDrive/dacon_growthperiod/open...   37      bc   BC_03
# 116  /content/drive/MyDrive/dacon_growthperiod/open...   38      bc   BC_03
# 117  /content/drive/MyDrive/dacon_growthperiod/open...   39      bc   BC_03
# 118  /content/drive/MyDrive/dacon_growthperiod/open...   40      bc   BC_03
# 119  /content/drive/MyDrive/dacon_growthperiod/open...   41      bc   BC_03
# 120  /content/drive/MyDrive/dacon_growthperiod/open...    1      bc   BC_04
# 121  /content/drive/MyDrive/dacon_growthperiod/open...    2      bc   BC_04
# 122  /content/drive/MyDrive/dacon_growthperiod/open...    4      bc   BC_04
# 123  /content/drive/MyDrive/dacon_growthperiod/open...    3      bc   BC_04
# 124  /content/drive/MyDrive/dacon_growthperiod/open...    5      bc   BC_04
# 125  /content/drive/MyDrive/dacon_growthperiod/open...    6      bc   BC_04
# 126  /content/drive/MyDrive/dacon_growthperiod/open...    7      bc   BC_04
# 127  /content/drive/MyDrive/dacon_growthperiod/open...    8      bc   BC_04
# 128  /content/drive/MyDrive/dacon_growthperiod/open...    9      bc   BC_04
# 129  /content/drive/MyDrive/dacon_growthperiod/open...   10      bc   BC_04
# 130  /content/drive/MyDrive/dacon_growthperiod/open...   11      bc   BC_04
# 169  /content/drive/MyDrive/dacon_growthperiod/open...    7      bc   BC_05
# 170  /content/drive/MyDrive/dacon_growthperiod/open...    8      bc   BC_05
# 171  /content/drive/MyDrive/dacon_growthperiod/open...   10      bc   BC_05
# 172  /content/drive/MyDrive/dacon_growthperiod/open...    9      bc   BC_05
# 173  /content/drive/MyDrive/dacon_growthperiod/open...   11      bc   BC_05
# 174  /content/drive/MyDrive/dacon_growthperiod/open...   12      bc   BC_05
# 175  /content/drive/MyDrive/dacon_growthperiod/open...   13      bc   BC_05
# 176  /content/drive/MyDrive/dacon_growthperiod/open...   14      bc   BC_05
# 177  /content/drive/MyDrive/dacon_growthperiod/open...   15      bc   BC_05
# 178  /content/drive/MyDrive/dacon_growthperiod/open...   16      bc   BC_05
# 179  /content/drive/MyDrive/dacon_growthperiod/open...   17      bc   BC_05
# 180  /content/drive/MyDrive/dacon_growthperiod/open...   18      bc   BC_05
# 181  /content/drive/MyDrive/dacon_growthperiod/open...   19      bc   BC_05
# 182  /content/drive/MyDrive/dacon_growthperiod/open...   20      bc   BC_05
# 183  /content/drive/MyDrive/dacon_growthperiod/open...   21      bc   BC_05
# 184  /content/drive/MyDrive/dacon_growthperiod/open...   22      bc   BC_05
# 185  /content/drive/MyDrive/dacon_growthperiod/open...   23      bc   BC_05
# 186  /content/drive/MyDrive/dacon_growthperiod/open...   24      bc   BC_05
# 187  /content/drive/MyDrive/dacon_growthperiod/open...   25      bc   BC_05
# 188  /content/drive/MyDrive/dacon_growthperiod/open...   26      bc   BC_05
# 189  /content/drive/MyDrive/dacon_growthperiod/open...   27      bc   BC_05
# 190  /content/drive/MyDrive/dacon_growthperiod/open...   28      bc   BC_05
# 191  /content/drive/MyDrive/dacon_growthperiod/open...   29      bc   BC_05
# 192  /content/drive/MyDrive/dacon_growthperiod/open...   30      bc   BC_05
# 193  /content/drive/MyDrive/dacon_growthperiod/open...   31      bc   BC_05
# 194  /content/drive/MyDrive/dacon_growthperiod/open...   32      bc   BC_05
# 195  /content/drive/MyDrive/dacon_growthperiod/open...   33      bc   BC_05
# 196  /content/drive/MyDrive/dacon_growthperiod/open...   34      bc   BC_05
# 197  /content/drive/MyDrive/dacon_growthperiod/open...   35      bc   BC_05
# 198  /content/drive/MyDrive/dacon_growthperiod/open...   36      bc   BC_05
# 199  /content/drive/MyDrive/dacon_growthperiod/open...   37      bc   BC_05
# 200  /content/drive/MyDrive/dacon_growthperiod/open...   38      bc   BC_05
# 201  /content/drive/MyDrive/dacon_growthperiod/open...   39      bc   BC_05
# 202  /content/drive/MyDrive/dacon_growthperiod/open...   40      bc   BC_05
# 203  /content/drive/MyDrive/dacon_growthperiod/open...    1      bc   BC_06
# 204  /content/drive/MyDrive/dacon_growthperiod/open...    2      bc   BC_06
# 205  /content/drive/MyDrive/dacon_growthperiod/open...    3      bc   BC_06
# 206  /content/drive/MyDrive/dacon_growthperiod/open...    4      bc   BC_06
# 207  /content/drive/MyDrive/dacon_growthperiod/open...    5      bc   BC_06
# 286  /content/drive/MyDrive/dacon_growthperiod/open...   43      bc   BC_07
# 287  /content/drive/MyDrive/dacon_growthperiod/open...    2      bc   BC_08
# 288  /content/drive/MyDrive/dacon_growthperiod/open...    3      bc   BC_08
# 289  /content/drive/MyDrive/dacon_growthperiod/open...    4      bc   BC_08
# 290  /content/drive/MyDrive/dacon_growthperiod/open...    5      bc   BC_08
# 291  /content/drive/MyDrive/dacon_growthperiod/open...    6      bc   BC_08
# 292  /content/drive/MyDrive/dacon_growthperiod/open...    7      bc   BC_08
# 293  /content/drive/MyDrive/dacon_growthperiod/open...    9      bc   BC_08
# 294  /content/drive/MyDrive/dacon_growthperiod/open...    8      bc   BC_08
# 295  /content/drive/MyDrive/dacon_growthperiod/open...   10      bc   BC_08
# 296  /content/drive/MyDrive/dacon_growthperiod/open...   11      bc   BC_08
# 297  /content/drive/MyDrive/dacon_growthperiod/open...   12      bc   BC_08
# 298  /content/drive/MyDrive/dacon_growthperiod/open...   13      bc   BC_08
# 299  /content/drive/MyDrive/dacon_growthperiod/open...   14      bc   BC_08
# 300  /content/drive/MyDrive/dacon_growthperiod/open...   15      bc   BC_08
# 301  /content/drive/MyDrive/dacon_growthperiod/open...   16      bc   BC_08
# 302  /content/drive/MyDrive/dacon_growthperiod/open...   17      bc   BC_08
# 303  /content/drive/MyDrive/dacon_growthperiod/open...   18      bc   BC_08
# 304  /content/drive/MyDrive/dacon_growthperiod/open...   19      bc   BC_08
# 305  /content/drive/MyDrive/dacon_growthperiod/open...   20      bc   BC_08
# 306  /content/drive/MyDrive/dacon_growthperiod/open...   21      bc   BC_08
# 307  /content/drive/MyDrive/dacon_growthperiod/open...   22      bc   BC_08
# 308  /content/drive/MyDrive/dacon_growthperiod/open...   23      bc   BC_08
# 309  /content/drive/MyDrive/dacon_growthperiod/open...   24      bc   BC_08
# 310  /content/drive/MyDrive/dacon_growthperiod/open...   25      bc   BC_08
# 311  /content/drive/MyDrive/dacon_growthperiod/open...   26      bc   BC_08
# 312  /content/drive/MyDrive/dacon_growthperiod/open...   27      bc   BC_08
# 313  /content/drive/MyDrive/dacon_growthperiod/open...   28      bc   BC_08
# 314  /content/drive/MyDrive/dacon_growthperiod/open...   29      bc   BC_08
# 315  /content/drive/MyDrive/dacon_growthperiod/open...   30      bc   BC_08
# 316  /content/drive/MyDrive/dacon_growthperiod/open...   31      bc   BC_08
# 317  /content/drive/MyDrive/dacon_growthperiod/open...   32      bc   BC_08
# 318  /content/drive/MyDrive/dacon_growthperiod/open...   33      bc   BC_08
# 319  /content/drive/MyDrive/dacon_growthperiod/open...   34      bc   BC_08
# 320  /content/drive/MyDrive/dacon_growthperiod/open...   35      bc   BC_08
# 321  /content/drive/MyDrive/dacon_growthperiod/open...   36      bc   BC_08
# 322  /content/drive/MyDrive/dacon_growthperiod/open...   37      bc   BC_08
# 323  /content/drive/MyDrive/dacon_growthperiod/open...    1      bc   BC_09
# 324  /content/drive/MyDrive/dacon_growthperiod/open...    2      bc   BC_09
# 325  /content/drive/MyDrive/dacon_growthperiod/open...    3      bc   BC_09
# 326  /content/drive/MyDrive/dacon_growthperiod/open...    4      bc   BC_09
# 327  /content/drive/MyDrive/dacon_growthperiod/open...    5      bc   BC_09
# 328  /content/drive/MyDrive/dacon_growthperiod/open...    6      bc   BC_09
# 329  /content/drive/MyDrive/dacon_growthperiod/open...    7      bc   BC_09
# 330  /content/drive/MyDrive/dacon_growthperiod/open...    8      bc   BC_09
# 331  /content/drive/MyDrive/dacon_growthperiod/open...    9      bc   BC_09
# 332  /content/drive/MyDrive/dacon_growthperiod/open...   10      bc   BC_09
# 333  /content/drive/MyDrive/dacon_growthperiod/open...   11      bc   BC_09
# 334  /content/drive/MyDrive/dacon_growthperiod/open...   12      bc   BC_09
# 335  /content/drive/MyDrive/dacon_growthperiod/open...   13      bc   BC_09
# 336  /content/drive/MyDrive/dacon_growthperiod/open...   14      bc   BC_09
# 337  /content/drive/MyDrive/dacon_growthperiod/open...   15      bc   BC_09
# 338  /content/drive/MyDrive/dacon_growthperiod/open...   16      bc   BC_09
# 339  /content/drive/MyDrive/dacon_growthperiod/open...   17      bc   BC_09
# 340  /content/drive/MyDrive/dacon_growthperiod/open...   18      bc   BC_09
# 341  /content/drive/MyDrive/dacon_growthperiod/open...   19      bc   BC_09
# 342  /content/drive/MyDrive/dacon_growthperiod/open...   20      bc   BC_09
# 343  /content/drive/MyDrive/dacon_growthperiod/open...   21      bc   BC_09
# 344  /content/drive/MyDrive/dacon_growthperiod/open...   22      bc   BC_09
# 345  /content/drive/MyDrive/dacon_growthperiod/open...   23      bc   BC_09
# 346  /content/drive/MyDrive/dacon_growthperiod/open...   24      bc   BC_09
# 347  /content/drive/MyDrive/dacon_growthperiod/open...   25      bc   BC_09
# 348  /content/drive/MyDrive/dacon_growthperiod/open...   26      bc   BC_09
# 349  /content/drive/MyDrive/dacon_growthperiod/open...   27      bc   BC_09
# 350  /content/drive/MyDrive/dacon_growthperiod/open...   28      bc   BC_09
# 351  /content/drive/MyDrive/dacon_growthperiod/open...   29      bc   BC_09
# 352  /content/drive/MyDrive/dacon_growthperiod/open...   30      bc   BC_09
# 353  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_01
# 354  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_01
# 355  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_01
# 356  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_01
# 357  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_01
# 358  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_01
# 359  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_01
# 360  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_01
# 361  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_01
# 362  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_01
# 363  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_01
# 364  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_01
# 365  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_01
# 366  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_01
# 367  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_01
# 368  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_01
# 369  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_01
# 370  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_01
# 371  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_01
# 372  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_01
# 373  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_01
# 374  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_01
# 375  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_01
# 376  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_01
# 377  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_01
# 378  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_01
# 379  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_01
# 380  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_01
# 381  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_01
# 382  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_01
# 383  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_01
# 384  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_01
# 385  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_01
# 386  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_01
# 387  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_01
# 388  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_01
# 389  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_01
# 390  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_01
# 391  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_01
# 392  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_01
# 393  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_02
# 394  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_02
# 395  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_02
# 396  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_02
# 397  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_02
# 398  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_02
# 399  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_02
# 400  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_02
# 401  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_02
# 402  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_02
# 403  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_02
# 404  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_02
# 405  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_02
# 406  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_02
# 407  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_02
# 408  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_02
# 409  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_02
# 410  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_02
# 411  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_02
# 412  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_02
# 413  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_02
# 414  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_02
# 415  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_02
# 416  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_02
# 417  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_02
# 418  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_02
# 419  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_02
# 420  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_02
# 421  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_02
# 422  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_02
# 423  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_02
# 424  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_02
# 425  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_02
# 426  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_02
# 427  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_02
# 428  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_02
# 429  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_02
# 430  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_02
# 431  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_02
# 432  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_02
# 433  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_03
# 434  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_03
# 435  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_03
# 436  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_03
# 437  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_03
# 438  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_03
# 439  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_03
# 440  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_03
# 441  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_03
# 442  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_03
# 443  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_03
# 444  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_03
# 445  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_03
# 446  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_03
# 447  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_03
# 448  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_03
# 449  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_03
# 450  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_03
# 451  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_03
# 452  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_03
# 453  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_03
# 454  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_03
# 455  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_03
# 456  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_03
# 457  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_03
# 458  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_03
# 459  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_03
# 460  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_03
# 461  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_03
# 462  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_03
# 463  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_03
# 464  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_03
# 465  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_03
# 466  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_03
# 467  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_03
# 468  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_03
# 469  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_03
# 470  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_03
# 471  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_03
# 472  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_03
# 473  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_04
# 474  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_04
# 475  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_04
# 476  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_04
# 477  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_04
# 478  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_04
# 479  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_04
# 480  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_04
# 481  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_04
# 482  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_04
# 483  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_04
# 484  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_04
# 485  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_04
# 486  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_04
# 487  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_04
# 488  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_04
# 489  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_04
# 490  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_04
# 491  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_04
# 492  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_04
# 493  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_04
# 494  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_04
# 495  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_04
# 496  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_04
# 497  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_04
# 498  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_04
# 499  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_04
# 500  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_04
# 501  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_04
# 502  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_04
# 503  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_04
# 504  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_04
# 505  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_04
# 506  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_04
# 507  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_04
# 508  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_04
# 509  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_04
# 510  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_04
# 511  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_04
# 512  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_04
# 513  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_05
# 514  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_05
# 515  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_05
# 516  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_05
# 517  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_05
# 518  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_05
# 519  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_05
# 520  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_05
# 521  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_05
# 522  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_05
# 523  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_05
# 524  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_05
# 525  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_05
# 526  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_05
# 527  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_05
# 528  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_05
# 529  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_05
# 530  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_05
# 531  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_05
# 532  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_05
# 533  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_05
# 534  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_05
# 535  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_05
# 536  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_05
# 537  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_05
# 538  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_05
# 539  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_05
# 540  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_05
# 541  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_05
# 542  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_05
# 543  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_05
# 544  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_05
# 545  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_05
# 546  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_05
# 547  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_05
# 548  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_05
# 549  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_05
# 550  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_05
# 551  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_05
# 552  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_05
# 553  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_06
# 554  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_06
# 555  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_06
# 556  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_06
# 557  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_06
# 558  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_06
# 559  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_06
# 560  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_06
# 561  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_06
# 562  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_06
# 563  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_06
# 564  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_06
# 565  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_06
# 566  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_06
# 567  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_06
# 568  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_06
# 569  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_06
# 570  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_06
# 571  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_06
# 572  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_06
# 573  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_06
# 574  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_06
# 575  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_06
# 576  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_06
# 577  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_06
# 578  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_06
# 579  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_06
# 580  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_06
# 581  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_06
# 582  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_06
# 583  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_06
# 584  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_06
# 585  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_06
# 586  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_06
# 587  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_06
# 588  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_06
# 589  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_06
# 590  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_06
# 591  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_06
# 592  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_07
# 593  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_07
# 594  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_07
# 595  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_07
# 596  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_07
# 597  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_07
# 598  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_07
# 599  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_07
# 600  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_07
# 601  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_07
# 602  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_07
# 603  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_07
# 604  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_07
# 605  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_07
# 606  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_07
# 607  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_07
# 608  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_07
# 609  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_07
# 610  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_07
# 611  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_07
# 612  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_07
# 613  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_07
# 614  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_07
# 615  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_07
# 616  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_07
# 617  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_07
# 618  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_07
# 619  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_07
# 620  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_07
# 621  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_07
# 622  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_07
# 623  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_07
# 624  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_07
# 625  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_07
# 626  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_07
# 627  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_07
# 628  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_07
# 629  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_07
# 630  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_07
# 631  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_07
# 632  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_08
# 633  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_08
# 634  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_08
# 635  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_08
# 636  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_08
# 637  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_08
# 638  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_08
# 639  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_08
# 640  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_08
# 641  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_08
# 642  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_08
# 643  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_08
# 644  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_08
# 645  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_08
# 646  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_08
# 647  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_08
# 648  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_08
# 649  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_08
# 650  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_08
# 651  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_08
# 652  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_08
# 653  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_08
# 654  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_08
# 655  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_08
# 656  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_08
# 657  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_08
# 658  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_08
# 659  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_08
# 660  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_08
# 661  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_08
# 662  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_08
# 663  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_08
# 664  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_08
# 665  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_08
# 666  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_08
# 667  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_08
# 668  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_08
# 669  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_08
# 670  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_08
# 671  /content/drive/MyDrive/dacon_growthperiod/open...   40      lt   LT_08
# 672  /content/drive/MyDrive/dacon_growthperiod/open...   41      lt   LT_08
# 673  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_09
# 674  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_09
# 675  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_09
# 676  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_09
# 677  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_09
# 678  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_09
# 679  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_09
# 680  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_09
# 681  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_09
# 682  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_09
# 683  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_09
# 684  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_09
# 685  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_09
# 686  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_09
# 687  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_09
# 688  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_09
# 689  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_09
# 690  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_09
# 691  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_09
# 692  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_09
# 693  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_09
# 694  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_09
# 695  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_09
# 696  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_09
# 697  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_09
# 698  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_09
# 699  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_09
# 700  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_09
# 701  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_09
# 702  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_09
# 703  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_09
# 704  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_09
# 705  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_09
# 706  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_09
# 707  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_09
# 708  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_09
# 709  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_09
# 710  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_09
# 711  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_09
# 712  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_09
# 713  /content/drive/MyDrive/dacon_growthperiod/open...    0      lt   LT_10
# 714  /content/drive/MyDrive/dacon_growthperiod/open...    1      lt   LT_10
# 715  /content/drive/MyDrive/dacon_growthperiod/open...    2      lt   LT_10
# 716  /content/drive/MyDrive/dacon_growthperiod/open...    3      lt   LT_10
# 717  /content/drive/MyDrive/dacon_growthperiod/open...    4      lt   LT_10
# 718  /content/drive/MyDrive/dacon_growthperiod/open...    5      lt   LT_10
# 719  /content/drive/MyDrive/dacon_growthperiod/open...    6      lt   LT_10
# 720  /content/drive/MyDrive/dacon_growthperiod/open...    7      lt   LT_10
# 721  /content/drive/MyDrive/dacon_growthperiod/open...    8      lt   LT_10
# 722  /content/drive/MyDrive/dacon_growthperiod/open...    9      lt   LT_10
# 723  /content/drive/MyDrive/dacon_growthperiod/open...   10      lt   LT_10
# 724  /content/drive/MyDrive/dacon_growthperiod/open...   11      lt   LT_10
# 725  /content/drive/MyDrive/dacon_growthperiod/open...   12      lt   LT_10
# 726  /content/drive/MyDrive/dacon_growthperiod/open...   13      lt   LT_10
# 727  /content/drive/MyDrive/dacon_growthperiod/open...   14      lt   LT_10
# 728  /content/drive/MyDrive/dacon_growthperiod/open...   15      lt   LT_10
# 729  /content/drive/MyDrive/dacon_growthperiod/open...   16      lt   LT_10
# 730  /content/drive/MyDrive/dacon_growthperiod/open...   17      lt   LT_10
# 731  /content/drive/MyDrive/dacon_growthperiod/open...   18      lt   LT_10
# 732  /content/drive/MyDrive/dacon_growthperiod/open...   19      lt   LT_10
# 733  /content/drive/MyDrive/dacon_growthperiod/open...   20      lt   LT_10
# 734  /content/drive/MyDrive/dacon_growthperiod/open...   21      lt   LT_10
# 735  /content/drive/MyDrive/dacon_growthperiod/open...   22      lt   LT_10
# 736  /content/drive/MyDrive/dacon_growthperiod/open...   23      lt   LT_10
# 737  /content/drive/MyDrive/dacon_growthperiod/open...   24      lt   LT_10
# 738  /content/drive/MyDrive/dacon_growthperiod/open...   25      lt   LT_10
# 739  /content/drive/MyDrive/dacon_growthperiod/open...   26      lt   LT_10
# 740  /content/drive/MyDrive/dacon_growthperiod/open...   27      lt   LT_10
# 741  /content/drive/MyDrive/dacon_growthperiod/open...   28      lt   LT_10
# 742  /content/drive/MyDrive/dacon_growthperiod/open...   29      lt   LT_10
# 743  /content/drive/MyDrive/dacon_growthperiod/open...   30      lt   LT_10
# 744  /content/drive/MyDrive/dacon_growthperiod/open...   31      lt   LT_10
# 745  /content/drive/MyDrive/dacon_growthperiod/open...   32      lt   LT_10
# 746  /content/drive/MyDrive/dacon_growthperiod/open...   33      lt   LT_10
# 747  /content/drive/MyDrive/dacon_growthperiod/open...   34      lt   LT_10
# 748  /content/drive/MyDrive/dacon_growthperiod/open...   35      lt   LT_10
# 749  /content/drive/MyDrive/dacon_growthperiod/open...   36      lt   LT_10
# 750  /content/drive/MyDrive/dacon_growthperiod/open...   37      lt   LT_10
# 751  /content/drive/MyDrive/dacon_growthperiod/open...   38      lt   LT_10
# 752  /content/drive/MyDrive/dacon_growthperiod/open...   39      lt   LT_10

# %%
def make_combination(species, data_frame):
    before_file_path = []
    after_file_path = []
    time_delta = []

    for version in data_frame[data_frame['species'] == species]['version'].unique():
        for i in range(0, len(data_frame[data_frame['version'] == version]) - 1):
            for j in range(i + 1, len(data_frame[data_frame['version'] == version])):
                after = data_frame[data_frame['version'] == version].iloc[j].reset_index(drop=True)
                before = data_frame[data_frame['version'] == version].iloc[i].reset_index(drop=True)

                before_file_path.append(before[0])
                after_file_path.append(after[0])

                delta = int(after[1] - before[1])
                time_delta.append(delta)


    combination_df = pd.DataFrame({
        'before_file_path': before_file_path,
        'after_file_path': after_file_path,
        'time_delta': time_delta,
    })

    combination_df['species'] = species

    return combination_df

bt_combination = make_combination('bc', total_dataframe)
lt_combination = make_combination('lt', total_dataframe)

bt_train = bt_combination
lt_train = lt_combination

train_set = pd.concat([bt_train, lt_train])
train_set
# Out:
#                                        before_file_path  \
# 0     /content/drive/MyDrive/dacon_growthperiod/open...
# 1     /content/drive/MyDrive/dacon_growthperiod/open...
# 2     /content/drive/MyDrive/dacon_growthperiod/open...
# 3     /content/drive/MyDrive/dacon_growthperiod/open...
# 4     /content/drive/MyDrive/dacon_growthperiod/open...
# ...                                                 ...
# 7796  /content/drive/MyDrive/dacon_growthperiod/open...
# 7797  /content/drive/MyDrive/dacon_growthperiod/open...
# 7798  /content/drive/MyDrive/dacon_growthperiod/open...
# 7799  /content/drive/MyDrive/dacon_growthperiod/open...
# 7800  /content/drive/MyDrive/dacon_growthperiod/open...
#
#                                         after_file_path  time_delta species
# 0     /content/drive/MyDrive/dacon_growthperiod/open...           1      bc
# 1     /content/drive/MyDrive/dacon_growthperiod/open...           2      bc
# 2     /content/drive/MyDrive/dacon_growthperiod/open...           3      bc
# 3     /content/drive/MyDrive/dacon_growthperiod/open...           4      bc
# 4     /content/drive/MyDrive/dacon_growthperiod/open...           5      bc
# ...                                                 ...         ...     ...
# 7796  /content/drive/MyDrive/dacon_growthperiod/open...           2      lt
# 7797  /content/drive/MyDrive/dacon_growthperiod/open...           3      lt
# 7798  /content/drive/MyDrive/dacon_growthperiod/open...           1      lt
# 7799  /content/drive/MyDrive/dacon_growthperiod/open...           2      lt
# 7800  /content/drive/MyDrive/dacon_growthperiod/open...           1      lt
#
# [14613 rows x 4 columns]

# %%
cd /content/drive/MyDrive/dacon_growthperiod/open/train_dataset
# Out:
# /content/drive/MyDrive/dacon_growthperiod/open/train_dataset

# %%
train_set.to_csv('train_set.csv')

# %%
train_set.reset_index(inplace=True, drop=True)

# %%
train_set.tail()
# Out:
#                                         before_file_path  \
# 14608  /content/drive/MyDrive/dacon_growthperiod/open...
# 14609  /content/drive/MyDrive/dacon_growthperiod/open...
# 14610  /content/drive/MyDrive/dacon_growthperiod/open...
# 14611  /content/drive/MyDrive/dacon_growthperiod/open...
# 14612  /content/drive/MyDrive/dacon_growthperiod/open...
#
#                                          after_file_path  time_delta species
# 14608  /content/drive/MyDrive/dacon_growthperiod/open...           2      lt
# 14609  /content/drive/MyDrive/dacon_growthperiod/open...           3      lt
# 14610  /content/drive/MyDrive/dacon_growthperiod/open...           1      lt
# 14611  /content/drive/MyDrive/dacon_growthperiod/open...           2      lt
# 14612  /content/drive/MyDrive/dacon_growthperiod/open...           1      lt

# %%
## train, validation directory 생성
train_dir = os.path.join(train_data_dir, 'train')
val_dir = os.path.join(train_data_dir, 'validation')
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

# %%
train_set.species.value_counts()
# Out:
# lt    7801
# bc    6812
# Name: species, dtype: int64

# %%
train_set[6806:6815]
# Out:
#                                        before_file_path  \
# 6806  /content/drive/MyDrive/dacon_growthperiod/open...
# 6807  /content/drive/MyDrive/dacon_growthperiod/open...
# 6808  /content/drive/MyDrive/dacon_growthperiod/open...
# 6809  /content/drive/MyDrive/dacon_growthperiod/open...
# 6810  /content/drive/MyDrive/dacon_growthperiod/open...
# 6811  /content/drive/MyDrive/dacon_growthperiod/open...
# 6812  /content/drive/MyDrive/dacon_growthperiod/open...
# 6813  /content/drive/MyDrive/dacon_growthperiod/open...
# 6814  /content/drive/MyDrive/dacon_growthperiod/open...
#
#                                         after_file_path  time_delta species
# 6806  /content/drive/MyDrive/dacon_growthperiod/open...           1      bc
# 6807  /content/drive/MyDrive/dacon_growthperiod/open...           2      bc
# 6808  /content/drive/MyDrive/dacon_growthperiod/open...           3      bc
# 6809  /content/drive/MyDrive/dacon_growthperiod/open...           1      bc
# 6810  /content/drive/MyDrive/dacon_growthperiod/open...           2      bc
# 6811  /content/drive/MyDrive/dacon_growthperiod/open...           1      bc
# 6812  /content/drive/MyDrive/dacon_growthperiod/open...           1      lt
# 6813  /content/drive/MyDrive/dacon_growthperiod/open...           2      lt
# 6814  /content/drive/MyDrive/dacon_growthperiod/open...           3      lt

# %%
train_set.species.replace('bc', 0, inplace=True)
train_set.species.replace('lt', 1, inplace=True)

# %%
train_set_shuffled = train_set.sample(frac=1).reset_index(drop=True)

# %%
df_train = train_set_shuffled[:int(14613*0.8)]

# %%
df_val = train_set_shuffled[int(14613*0.8):]

# %% [markdown]
# # to-tfrecord

# %%
# The following functions can be used to convert a value to a type compatible
# with tf.Example.

def _bytes_feature(value):
  """Returns a bytes_list from a string / byte."""
  if isinstance(value, type(tf.constant(0))):
    value = value.numpy() # BytesList won't unpack a string from an EagerTensor.
  return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _float_feature(value):
  """Returns a float_list from a float / double."""
  return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))

def _int64_feature(value):
  """Returns an int64_list from a bool / enum / int / uint."""
  return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

# %%
## TFRecord 저장할 directory와 file 경로 설정
tfr_dir = os.path.join(train_data_dir, 'tfrecord')
os.makedirs(tfr_dir, exist_ok=True)
tfr_train_dir = os.path.join(tfr_dir, 'cls_train.tfr')
## TFRecord writer 생성
writer_train = tf.io.TFRecordWriter(tfr_train_dir)
df_train.species.value_counts()
# Out:
# 1    6233
# 0    5457
# Name: species, dtype: int64

# %%
df_train.tail()
# Out:
#                                         before_file_path  \
# 11685  /content/drive/MyDrive/dacon_growthperiod/open...
# 11686  /content/drive/MyDrive/dacon_growthperiod/open...
# 11687  /content/drive/MyDrive/dacon_growthperiod/open...
# 11688  /content/drive/MyDrive/dacon_growthperiod/open...
# 11689  /content/drive/MyDrive/dacon_growthperiod/open...
#
#                                          after_file_path  time_delta  species
# 11685  /content/drive/MyDrive/dacon_growthperiod/open...           3        1
# 11686  /content/drive/MyDrive/dacon_growthperiod/open...          10        1
# 11687  /content/drive/MyDrive/dacon_growthperiod/open...          21        1
# 11688  /content/drive/MyDrive/dacon_growthperiod/open...          22        1
# 11689  /content/drive/MyDrive/dacon_growthperiod/open...          24        1

# %%
  before_image = Image.open(df_train.iloc[0].before_file_path)
  before_image = before_image.resize((224, 224))
  before_bimage = before_image.tobytes()

  after_image = Image.open(df_train.iloc[0].after_file_path)
  after_image = after_image.resize((224, 224))
  after_bimage = after_image.tobytes()

# %%
before_image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA7D08AAD10>

# %%
after_image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA7D0997590>

# %%
pil_image = Image.fromarray(np.array(before_image) - np.array(after_image))
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA7D043C750>

# %%
n_train = 0

for i, v in tqdm(df_train.iterrows()):
  before_image = Image.open(v.before_file_path)
  before_image = before_image.resize((224, 224))

  after_image = Image.open(v.after_file_path)
  after_image = after_image.resize((224, 224))

  delta = Image.fromarray(np.array(before_image) - np.array(after_image))
  bdelta = delta.tobytes()

  td = v.time_delta
  sp = v.species

  example = tf.train.Example(features=tf.train.Features(feature={
      'delta': _bytes_feature(bdelta),
      'time_delta': _int64_feature(td),
      'species': _int64_feature(sp)
  }))

  writer_train.write(example.SerializeToString())
  n_train += 1

writer_train.close()
print(n_train)
# Out:
# 11690it [2:15:15,  1.44it/s]
# 11690

# %%
tfr_val_dir = os.path.join(tfr_dir, 'cls_val.tfr')
writer_val = tf.io.TFRecordWriter(tfr_val_dir)

# %%
n_val = 0

for i, v in df_val.iterrows():
  before_image = Image.open(v.before_file_path)
  before_image = before_image.resize((224, 224))

  after_image = Image.open(v.after_file_path)
  after_image = after_image.resize((224, 224))

  delta = Image.fromarray(np.array(before_image) - np.array(after_image))
  bdelta = delta.tobytes()

  td = v.time_delta
  sp = v.species

  example = tf.train.Example(features=tf.train.Features(feature={
      'delta': _bytes_feature(bdelta),
      'time_delta': _int64_feature(td),
      'species': _int64_feature(sp)
  }))

  writer_val.write(example.SerializeToString())
  n_val += 1

writer_val.close()
print(n_val)
# Out:
# 2923
